# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
pd.set_option('display.max_columns',50)
import featuretools as ft
import seaborn as sns

# %%
#reading the datasets
train=pd.read_csv("Train.csv")
test=pd.read_csv('Test.csv')

# %%
split=train.shape[0]
datasets=pd.concat([train,test],axis=0)

# %%
datasets.tail(2)
# Out:
#        age_of_respondent bank_account cellphone_access country  \
# 10084                 28          NaN              Yes  Uganda
# 10085                 16          NaN              Yes  Uganda
#
#            education_level gender_of_respondent  household_size  \
# 10084    Primary education               Female               6
# 10085  Secondary education                 Male               7
#
#             job_type location_type           marital_status  \
# 10084  Self employed         Rural  Married/Living together
# 10085   Other Income         Urban     Single/Never Married
#
#       relationship_with_head       uniqueid  year
# 10084                 Spouse  uniqueid_3001  2018
# 10085         Other relative  uniqueid_3002  2018

# %%
datasets.drop(['uniqueid'],inplace=True,axis=1)

# %% [markdown]
# # Working On numerical data

# %%
#age
print("Maximum Age",datasets['age_of_respondent'].max())
print("Minimun Age",datasets['age_of_respondent'].min())
print("Missing values",datasets['age_of_respondent'].isnull().any())
# Out:
# Maximum Age 100
# Minimun Age 16
# Missing values False

# %%
#Visualizing Age
fig,ax=plt.subplots()
fig.set_size_inches(25,10)
sns.countplot(x='age_of_respondent',data=datasets)
ax.set_xlabel('Age of Respondent',fontsize=15)
ax.set_ylabel('count',fontsize=15)
ax.set_title("Age Distrinution",fontsize=15)
sns.despine()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(15,5))
sns.boxplot(x='age_of_respondent',data=datasets,orient='v',ax=ax1)
ax1.set_xlabel('pple''s_respondent',fontsize=15)
ax1.set_ylabel('age_of_respondent',fontsize=15)
ax1.set_title('Age Distribution')
ax1.tick_params(labelsize=15)

sns.distplot(datasets['age_of_respondent'],ax=ax2)
ax2.set_xlabel('Age_of_responden',fontsize=15)
ax2.set_ylabel('Occurrence',fontsize=15)
ax2.set_title("Age occurrence")
sns.despine(ax=ax2)
ax2.tick_params(labelsize=15)

# %%
#Calculating quartiles
print('1st quartile',datasets['age_of_respondent'].quantile(q=0.25))
print('2nd quartile',datasets['age_of_respondent'].quantile(q=0.5))
print('3rd quartile',datasets['age_of_respondent'].quantile(q=0.75))
print('4th quartile',datasets['age_of_respondent'].quantile(q=1))
# Out:
# 1st quartile 26.0
# 2nd quartile 35.0
# 3rd quartile 49.0
# 4th quartile 100.0

# %%
#checking for possibility of outliers in age
'''
InterquartileRange,IQR=Q3-Q1
lower 1.5*IQR whisker=Q1-1.5*IQR
upper 1.5*IQR whisker=Q3+1.5*IQR
'''
print('Ages Above',datasets['age_of_respondent'].quantile(q=0.75)+1.5*(datasets['age_of_respondent'].quantile(q=0.75)-datasets['age_of_respondent'].quantile(q=0.25)),'are outliers')
# Out:
# Ages Above 83.5 are outliers

# %%
#print number of outliers
print('number of outliers',datasets[datasets['age_of_respondent']>83.5]['age_of_respondent'].count())
print('% outliers',datasets[datasets['age_of_respondent']>83.5]['age_of_respondent'].count()/len(datasets)*100,'%')
# Out:
# number of outliers 327
# % outliers 0.9729247247842904 %

# %%
#trying to use values to calculate this variable
print("Mean:",datasets['age_of_respondent'].mean())
#1.Lower std means datapoints tend to be close to the mean
#2.higher std means datapoints are scattered
print("Std:",datasets['age_of_respondent'].std())
#i'm using coefficient Variation to give precise insight;std/mean*100
#cv<15......lower dispersion
#cv>30%..highr dispersion
print("CV",datasets['age_of_respondent'].std()/datasets['age_of_respondent'].mean()*100)
# Out:
# Mean: 38.656114251710804
# Std: 16.447127405614
# CV 42.54728578904203

# %% [raw]
# my conclusion is,since we have a high dispersion,we have people with all ages therefore we cannot conclude that age has a high effect to our target variable.I'll try fitting  model with and without this outliers

# %% [markdown]
# ## 2.Household size

# %%
print("Maximum Age",datasets['household_size'].max())
print("Minimun Age",datasets['household_size'].min())
print("Missing values",datasets['household_size'].isnull().any())
# Out:
# Maximum Age 21
# Minimun Age 0
# Missing values False

# %%
#Visualizing Age
fig,ax=plt.subplots()
fig.set_size_inches(25,10)
sns.countplot(x='household_size',data=datasets)
ax.set_xlabel('household_size',fontsize=15)
ax.set_ylabel('count',fontsize=15)
ax.set_title("household_size Distribution",fontsize=15)
sns.despine()

# %%
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(15,5))
sns.boxplot(x='household_size',data=datasets,orient='v',ax=ax1)
ax1.set_xlabel('pple''s_respondent',fontsize=15)
ax1.set_ylabel('household_size',fontsize=15)
ax1.set_title('household_size Distribution')
ax1.tick_params(labelsize=15)

sns.distplot(datasets['household_size'],ax=ax2)
ax2.set_xlabel('household_size',fontsize=15)
ax2.set_ylabel('Occurrence',fontsize=15)
ax2.set_title("household_size occurrence")
sns.despine(ax=ax2)
ax2.tick_params(labelsize=15)

# %% [markdown]
# ## Categorical variables

# %%
#1.job_type
# What kind of jobs clients this bank have, if you cross jobs with default, loan or housing, there is no relation
fig, ax = plt.subplots()
fig.set_size_inches(20, 5)
sns.countplot(x = 'job_type', data = datasets)
ax.set_xlabel('job_type', fontsize=10)
ax.set_ylabel('Count', fontsize=10)
ax.set_title('job Count Distribution', fontsize=10)
ax.tick_params(labelsize=10)
sns.despine()

# %% [markdown]
# ### 2.Marital Status

# %%
# What kind of 'marital clients' this bank have, if you cross marital with default, loan or housing, there is no relation
fig, ax = plt.subplots()
fig.set_size_inches(20, 5)
sns.countplot(x = 'marital_status', data = datasets)
ax.set_xlabel('Marital', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('marital Count Distribution', fontsize=15)
ax.tick_params(labelsize=15)
sns.despine()

# %% [markdown]
# ### 3.Education Level

# %%
# What kind of 'education clients this bank have, if you cross education with default, loan or housing, there is no relation
fig, ax = plt.subplots()
fig.set_size_inches(25, 5)
sns.countplot(x = 'education_level', data = datasets)
ax.set_xlabel('Education', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('Education Count Distribution', fontsize=15)
ax.tick_params(labelsize=15)
sns.despine()

# %% [markdown]
# ### 4.Country

# %%
# What kind of 'education clients this bank have, if you cross education with default, loan or housing, there is no relation
fig, ax = plt.subplots()
fig.set_size_inches(25, 5)
sns.countplot(x = 'country', data = datasets)
ax.set_xlabel('country', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('country', fontsize=15)
ax.tick_params(labelsize=15)
sns.despine()

# %% [markdown]
# ### 5.location

# %%
fig, ax = plt.subplots()
fig.set_size_inches(25, 5)
sns.countplot(x = 'location_type', data = datasets)
ax.set_xlabel('location_type', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('location', fontsize=15)
ax.tick_params(labelsize=15)
sns.despine()

# %% [markdown]
# ### 6.Cellophone access

# %%
fig, ax = plt.subplots()
fig.set_size_inches(25, 5)
sns.countplot(x = 'cellphone_access', data = datasets)
ax.set_xlabel('cellphone_access', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('cellphone_access', fontsize=15)
ax.tick_params(labelsize=15)
sns.despine()

# %% [markdown]
# # 7.Gender

# %%
fig, ax = plt.subplots()
fig.set_size_inches(25, 5)
sns.countplot(x = 'gender_of_respondent', data = datasets)
ax.set_xlabel('gender_of_respondent', fontsize=15)
ax.set_ylabel('Count', fontsize=15)
ax.set_title('gender_of_respondent', fontsize=15)
ax.tick_params(labelsize=15)
sns.despine()

# %% [markdown]
# # Feature Engineering

# %%
#datasets.age_of_respondent=pd.cut(datasets.age_of_respondent,[0,13,31,51,100],labels=['ChildAge','YoungAge','MiddleAge','SeniorAge'])

# %%
#Dummify the variables
#datasets = pd.get_dummies(datasets, columns=['age_of_respondent'], drop_first=True, prefix=['age_of_respondentr'])

# %%
datasets.head()
# Out:
#    age_of_respondent bank_account cellphone_access country  \
# 0                 24          Yes              Yes   Kenya
# 1                 70           No               No   Kenya
# 2                 26          Yes              Yes   Kenya
# 3                 34           No              Yes   Kenya
# 4                 26           No               No   Kenya
#
#                    education_level gender_of_respondent  household_size  \
# 0              Secondary education               Female               3
# 1              No formal education               Female               5
# 2  Vocational/Specialised training                 Male               5
# 3                Primary education               Female               5
# 4                Primary education                 Male               8
#
#                     job_type location_type           marital_status  \
# 0              Self employed         Rural  Married/Living together
# 1       Government Dependent         Rural                  Widowed
# 2              Self employed         Urban     Single/Never Married
# 3  Formally employed Private         Rural  Married/Living together
# 4        Informally employed         Urban     Single/Never Married
#
#   relationship_with_head  year  age_div_hs  age_sub_hs  log10_age  log100_age  \
# 0                 Spouse  2018        8.00          21        2.4        0.24
# 1      Head of Household  2018       14.00          65        7.0        0.70
# 2         Other relative  2018        5.20          21        2.6        0.26
# 3      Head of Household  2018        6.80          29        3.4        0.34
# 4                  Child  2018        3.25          18        2.6        0.26
#
#    agevsdiv_hs  agevssub_hs  log10vslog100  Agelog  log10_household  agelog10  \
# 0        16.00            3           2.16   13.84             -0.6      21.6
# 1        56.00            5           6.30   49.70              2.0      63.0
# 2        20.80            5           2.34   18.46             -2.4      23.4
# 3        27.20            5           3.06   24.14             -1.6      30.6
# 4        22.75            8           2.34   20.41             -5.4      23.4
#
#    year_log10  year_log100  year_age   yearage2  yearhousehold
# 0       201.8        20.18      1994  84.083333     672.666667
# 1       201.8        20.18      1948  28.828571     403.600000
# 2       201.8        20.18      1992  77.615385     403.600000
# 3       201.8        20.18      1984  59.352941     403.600000
# 4       201.8        20.18      1992  77.615385     252.250000

# %%
corr=datasets.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_b734af60_c882_11e9_a571_732991cc0b89row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col1 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col3 {
#             background-color:  #f4987a;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col4 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col7 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col8 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col9 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col10 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col11 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col12 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col13 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col14 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row0_col17 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col2 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col4 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col5 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col6 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col7 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col8 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col9 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col10 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col12 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col13 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col14 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col15 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col16 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row1_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col0 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col1 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col3 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col4 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col5 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col6 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col7 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col8 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col9 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col10 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col11 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col12 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col13 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col14 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col15 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col16 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row2_col17 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row3_col0 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row3_col1 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row3_col2 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row3_col4 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_b734af60_c882_11e9_a571_732991cc0b89row3_col5 {
#             background-color:  #ee8669;

# %%
datasets.shape
# Out:
# (33610, 27)

# %%
ft.primitives.list_primitives()
# Out:
#                                name         type  \
# 0                        num_unique  aggregation
# 1                            median  aggregation
# 2                               max  aggregation
# 3                   time_since_last  aggregation
# 4                  avg_time_between  aggregation
# 5                               sum  aggregation
# 6                               all  aggregation
# 7                               min  aggregation
# 8                     n_most_common  aggregation
# 9                               any  aggregation
# 10                             mode  aggregation
# 11                     percent_true  aggregation
# 12                 time_since_first  aggregation
# 13                             last  aggregation
# 14                             mean  aggregation
# 15                         num_true  aggregation
# 16                            count  aggregation
# 17                              std  aggregation
# 18                            trend  aggregation
# 19                             skew  aggregation
# 20            greater_than_equal_to    transform
# 21  scalar_subtract_numeric_feature    transform
# 22                         absolute    transform
# 23                        haversine    transform
# 24                       percentile    transform
# 25                     greater_than    transform
# 26                 subtract_numeric    transform
# 27                           negate    transform
# 28                       time_since    transform
# 29                      add_numeric    transform
# ..                              ...          ...
# 45                         cum_mean    transform
# 46     greater_than_equal_to_scalar    transform
# 47                 multiply_numeric    transform
# 48                         latitude    transform
# 49              time_since_previous    transform
# 50                          cum_sum    transform
# 51              greater_than_scalar    transform
# 52          subtract_numeric_scalar    transform
# 53                          is_null    transform
# 54                              not    transform
# 55               add_numeric_scalar    transform
# 56                       is_weekend    transform
# 57                             diff    transform
# 58                        num_words    transform
# 59                        longitude    transform
# 60                              and    transform
# 61                 not_equal_scalar    transform
# 62                            month    transform
# 63                          weekday    transform
# 64                     equal_scalar    transform
# 65            modulo_numeric_scalar    transform
# 66                           minute    transform
# 67            divide_numeric_scalar    transform
# 68        less_than_equal_to_scalar    transform
# 69                             hour    transform
# 70                          cum_min    transform
# 71                        less_than    transform
# 72                 less_than_scalar    transform
# 73          multiply_numeric_scalar    transform
# 74                        cum_count    transform
#
#                                           description
# 0   Determines the number of distinct values, igno...
# 1   Determines the middlemost number in a list of ...
# 2   Calculates the highest value, ignoring `NaN` v...
# 3   Calculates the time elapsed since the last dat...
# 4   Computes the average number of seconds between...
# 5      Calculates the total addition, ignoring `NaN`.
# 6      Calculates if all values are 'True' in a list.
# 7   Calculates the smallest value, ignoring `NaN` ...
# 8            Determines the `n` most common elements.
# 9        Determines if any value is 'True' in a list.
# 10       Determines the most commonly repeated value.
# 11           Determines the percent of `True` values.
# 12  Calculates the time elapsed since the first da...
# 13               Determines the last value in a list.
# 14         Computes the average for a list of values.
# 15                Counts the number of `True` values.
# 16  Determines the total number of values, excludi...
# 17  Computes the dispersion relative to the mean v...
# 18      Calculates the trend of a variable over time.
# 19  Computes the extent to which a distribution di...
# 20  Determines if values in one list are greater t...
# 21  Subtract each value in the list from a given s...
# 22           Computes the absolute value of a number.
# 23  Calculates the approximate haversine distance ...
# 24  Determines the percentile rank for each value ...
# 25  Determines if values in one list are greater t...
# 26             Element-wise subtraction of two lists.
# 27                           Negates a numeric value.
# 28  Calculates time from a value to a specified cu...
# 29                Element-wise addition of two lists.
# ..                                                ...
# 45                    Calculates the cumulative mean.
# 46  Determines if values are greater than or equal...
# 47          Element-wise multiplication of two lists.
# 48  Returns the first tuple value in a list of Lat...
# 49  Compute the time since the previous entry in a...
# 50                     Calculates the cumulative sum.
# 51  Determines if values are greater than a given ...
# 52   Subtract a scalar from each element in the list.
# 53                     Determines if a value is null.
# 54                           Negates a boolean value.
# 55            Add a scalar to each value in the list.
# 56           Determines if a date falls on a weekend.
# 57  Compute the difference between the value in a ...
# 58  Determines the number of words in a string by ...
# 59  Returns the second tuple value in a list of La...
# 60             Element-wise logical AND of two lists.
# 61  Determines if values in a list are not equal t...
# 62          Determines the month value of a datetime.
# 63    Determines the day of the week from a datetime.
# 64  Determines if values in a list are equal to a ...
# 65  Return the modulo of each element in the list ...
# 66        Determines the minutes value of a datetime.
# 67       Divide each element in the list by a scalar.
# 68  Determines if values are less than or equal to...
# 69           Determines the hour value of a datetime.
# 70                 Calculates the cumulative minimum.
# 71  Determines if values in one list are less than...
# 72  Determines if values are less than a given sca...
# 73     Multiply each element in the list by a scalar.
# 74                   Calculates the cumulative count.
#
# [75 rows x 3 columns]

# %%
datasets1=pd.get_dummies(datasets['country'], drop_first=True)
datasets2=pd.get_dummies(datasets['year'], drop_first=True)
datasets3=pd.get_dummies(datasets['location_type'], drop_first=True)
datasets4=pd.get_dummies(datasets['cellphone_access'], drop_first=True)
datasets5=pd.get_dummies(datasets['gender_of_respondent'], drop_first=True)
datasets6=pd.get_dummies(datasets['relationship_with_head'], drop_first=True)
datasets7=pd.get_dummies(datasets['marital_status'], drop_first=True)
datasets8=pd.get_dummies(datasets['education_level'], drop_first=True)
datasets9=pd.get_dummies(datasets['job_type'], drop_first=True)

# %%
datasets=datasets.drop(['country'], axis=1)
datasets=datasets.drop(['year'], axis=1)
datasets=datasets.drop(['location_type'], axis=1)
datasets=datasets.drop(['cellphone_access'], axis=1)
datasets=datasets.drop(['gender_of_respondent'], axis=1)
datasets=datasets.drop(['relationship_with_head'], axis=1)
datasets=datasets.drop(['marital_status'], axis=1)
datasets=datasets.drop(['education_level'], axis=1)
datasets=datasets.drop(['job_type'], axis=1)

# %%
#now we combine all datasets together
datasets=pd.concat([datasets,datasets1,datasets2,datasets3,datasets4,datasets5,datasets6,datasets7,datasets8,datasets9], axis=1)

# %%
datasets["bank_account"] = pd.get_dummies(datasets['bank_account'], columns = ['bank_account'], prefix = ['bank_account'], drop_first = True)

# %%
train=datasets[:split]
test=datasets[split:]

# %%
test.drop(['bank_account'],axis=1,inplace=True)

# %%
test.shape
# Out:
# (10086, 49)

# %%
X  = train.drop('bank_account',axis = 1)
y = train['bank_account']

# %%
# Splitting the dataset into the Training set and validation set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40, random_state =0)

# %%
# Fitting XGBoost to the Training set
from xgboost import XGBClassifier
classifier = XGBClassifier(n_estimators=200)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)
#metrics
import sklearn
sklearn.metrics.accuracy_score(y_test, y_pred, normalize=True, sample_weight=None)
# Out:
# 0.8866099893730074

# %%
predictions = classifier.predict(test)

# %%
test1=pd.read_csv('Test.csv')
test1['unique_id'] = test1[['uniqueid','country']].apply(lambda x: ' x '.join(x), axis=1)

# %%
submission = pd.DataFrame()
submission['unique_id'] = test1['unique_id']
submission['bank_account'] = predictions.reshape((predictions.shape[0]))
submission.to_csv('sub24.csv',index=False)

# %%
data2=pd.read_csv("sub24.csv")

# %%
data2['bank2']=test['age_of_respondent']

# %%
data2.head()
# Out:
#                unique_id  bank_account  bank2
# 0  uniqueid_6056 x Kenya             1     30
# 1  uniqueid_6060 x Kenya             1     51
# 2  uniqueid_6065 x Kenya             0     77
# 3  uniqueid_6072 x Kenya             0     39
# 4  uniqueid_6073 x Kenya             0     16

# %%
data2.drop(["bank_account",'bank2'],inplace=True,axis=1)

# %%
data2.rename({"pubHolidays":"bank_account"},inplace=True,axis=1)

# %%
data2.head()
# Out:
#                unique_id  bank_account
# 0  uniqueid_6056 x Kenya             1
# 1  uniqueid_6060 x Kenya             1
# 2  uniqueid_6065 x Kenya             0
# 3  uniqueid_6072 x Kenya             0
# 4  uniqueid_6073 x Kenya             0

# %%
data2.to_csv("indaba.csv",index=False)
